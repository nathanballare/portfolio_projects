# %% [markdown]
# # Project Summary: Object Detection with YOLO
#
# ## Description
#
# In this project, I built an object detection model using the YOLO (You Only Look Once) architecture. The main objective was to create a model capable of detecting various objects within images.
# ## Project Steps
#
# 1. **Import and Install Dependencies:** Started by importing the necessary libraries and ensuring all required dependencies were properly installed.
#
# 2. **Load Model:** Loaded a pre-trained YOLO model that had been trained on a vast dataset containing a wide variety of objects. This served as the foundation for our object detection efforts.
#
# 3. **Make Detections With Images:** Utilized the loaded YOLO model to make object detections on static images. The model's ability to identify different objects within images was evaluated.
#
# 4. **Real Time Detections:** Extended the project to include real-time object detection capabilities. Integrated the YOLO model with live video input, enabling the model to detect and label objects in real time.

# %% [markdown]
# 1. Import and Install Dependencies

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Acesso negado: 'C:\\Users\\natha\\anaconda3\\Lib\\site-packages\\~umpy\\.libs\\libopenblas64__v0.3.21-gcc_10_3_0.dll'
# Consider using the `--user` option or check the permissions.
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# 2. Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# C:\Users\natha\anaconda3\lib\site-packages\torch\hub.py:286: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\natha/.cache\torch\hub\master.zip
# YOLOv5  2023-8-31 Python-3.9.7 torch-2.0.1+cu118 CPU
# [Errno 2] No such file or directory: 'c:\\users\\natha\\anaconda3\\lib\\site-packages\\numpy-1.24.3.dist-info\\METADATA'
# ...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %% [markdown]
# 3. Make Detections With Images

# %%
# !pip install Pillow

# %%
import requests
from PIL import Image
from io import BytesIO

# URL of the image
img_url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e4/Cars_in_traffic_in_Auckland%2C_New_Zealand_-_copyright-free_photo_released_to_public_domain.jpg/800px-Cars_in_traffic_in_Auckland%2C_New_Zealand_-_copyright-free_photo_released_to_public_domain.jpg'

# Download the image
response = requests.get(img_url)
image_content = BytesIO(response.content)

# Open the image using PIL
img = Image.open(image_content)

# Now you can pass the PIL image to your model
results = model(img)
results.print()
# Out:
# image 1/1: 533x800 28 cars, 5 trucks
# Speed: 73.4ms pre-process, 534.3ms inference, 24.3ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()
# Out:
# [array([[[251, 216, 174],
#          [254, 219, 177],
#          [246, 213, 168],
#          ...,
#          [128, 148, 146],
#          [ 70,  79,  52],
#          [ 64,  71,  29]],
#
#         [[235, 201, 156],
#          [234, 200, 155],
#          [221, 189, 142],
#          ...,
#          [122, 141, 139],
#          [ 85,  91,  65],
#          [ 47,  52,  11]],
#
#         [[253, 219, 171],
#          [245, 213, 164],
#          [212, 180, 131],
#          ...,
#          [136, 155, 153],
#          [ 69,  73,  46],
#          [ 60,  62,  22]],
#
#         ...,
#
#         [[ 61,  69,  80],
#          [ 64,  72,  83],
#          [ 61,  69,  80],
#          ...,
#          [ 47,  52,  56],
#          [ 48,  53,  57],
#          [ 49,  54,  58]],
#
#         [[ 56,  64,  75],
#          [ 72,  80,  91],
#          [ 70,  78,  89],
#          ...,
#          [ 48,  53,  57],
#          [ 48,  53,  57],
#          [ 50,  55,  59]],
#
#         [[ 64,  72,  83],
# ...

# %% [markdown]
# 4. Real Time Detections

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Conclusion
#
# By utilizing the YOLO architecture, I successfully developed an object detection model capable of identifying diverse objects within images. The model's real-time capabilities were extended to webcam input, allowing for dynamic and interactive object detection. This project highlights the power of deep learning techniques in computer vision tasks and demonstrates how YOLO can be leveraged to create accurate and efficient object detection systems.
